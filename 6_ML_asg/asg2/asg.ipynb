# %% [markdown]
# # <center> Machine Learning Assignment #2 </center>
#
# This ipython notebook is work of **Adheesh Trivedi**.

# %% [markdown]
# ### Loading and plotting the dataset

# %%
import numpy as np

data = np.loadtxt('data.csv', delimiter=',', skiprows=1)

# %%
# Constants to be used throughout the notebook

N = data.shape[0]
K = 3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.scatter(data[:, 0], data[:, 1], s = 20, c = 'k')
plt.title('Raw data')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trying out different clustering techniques
#
# ### Measuring performance
#
# #### Silhouette Score
#
# Measures how similar a point is to its own cluster compared to other clusters.
# Range: $[-1, 1]$
#
# - Values closer to one indicates well-clustered.
# - Negative values: Points are likely misclassified.
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# #### Davies-Bouldin Index
#
# Measures the average ratio of intra-cluster distance to inter-cluster separation.
# Lower values indicate better clustering.
#
# $$
#     DB = \frac{1}{k} \Sigma_{i=1}^k \max_{i\neq j} \frac{s_i + s_j}{d_{ij}}
# $$
# ​
# $s_i$ : Average distance of points in cluster $i$ to their centroid.
#
# $d_{ij}$ : Distance between centroids of clusters $i$ and $j$.

# %%
from sklearn.base import ClusterMixin, BaseEstimator
from sklearn.metrics import silhouette_score, davies_bouldin_score

def apply_model(
    model : ClusterMixin or BaseEstimator, points : np.ndarray[int], title : str
    ):
    """
    This function applies the clustering model passed
    and plots the clusters. If the model predicts -1 then
    the data point is considered as noise.
    """

    clusters = model.fit_predict(points)

    silhouette = silhouette_score(points, clusters)
    davies_bouldin = davies_bouldin_score(points, clusters)

    print(f'Silhouette Score: {silhouette:.3f}')
    print(f'Davies-Bouldin Score: {davies_bouldin:.3f}')

    plt.figure(figsize=(10,6))
    plt.title(title)

    plt.scatter(points[clusters != -1, 0], points[clusters != -1, 1], s = 20, c = clusters[clusters != -1], cmap = 'cividis')
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\adhtr\scoop\apps\python39\current\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\adhtr\AppData\Local\Temp\ipykernel_29140\1919181053.py", line 1, in <module>
#     from sklearn.base import ClusterMixin, BaseEstimator
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\__init__.py", line 84, in <module>
#     from .base import clone
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\__init__.py", line 11, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\_chunking.py", line 8, in <module>
#     from ._param_validation import Interval, validate_params
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\_param_validation.py", line 14, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\validation.py", line 26, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\_array_api.py", line 11, in <module>
#     from .fixes import parse_version
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\fixes.py", line 24, in <module>
#     import pandas as pd
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pandas\__init__.py", line 57, in <module>
#     from pandas.compat import (
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\adhtr\scoop\apps\python39\current\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\adhtr\AppData\Roaming\Python\Python39\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\adhtr\AppData\Local\Temp\ipykernel_29140\1919181053.py", line 1, in <module>
#     from sklearn.base import ClusterMixin, BaseEstimator
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\__init__.py", line 84, in <module>
#     from .base import clone
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\__init__.py", line 11, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\_chunking.py", line 8, in <module>
#     from ._param_validation import Interval, validate_params
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\_param_validation.py", line 14, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\validation.py", line 26, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\_array_api.py", line 11, in <module>
#     from .fixes import parse_version
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\sklearn\utils\fixes.py", line 24, in <module>
#     import pandas as pd
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "c:\Users\adhtr\scoop\apps\python39\current\lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# ### K-Means Clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(3, algorithm = 'lloyd')

apply_model(kmeans, data, 'KMeans Clustering')
# Out:
# Silhouette Score: 0.421
# Davies-Bouldin Score: 0.831

# %% [markdown]
# ### Agglomerative clustering

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(3, linkage='complete')

apply_model(agg, data, 'Agglomerative Clustering (average linkage)')
# Out:
# Silhouette Score: 0.261
# Davies-Bouldin Score: 1.349

# %%
agg = AgglomerativeClustering(3, linkage='single')

apply_model(agg, data, 'Agglomerative Clustering (single linkage)')
# Out:
# Silhouette Score: -0.322
# Davies-Bouldin Score: 2.081

# %%
agg = AgglomerativeClustering(3, linkage='average')

apply_model(agg, data, 'Agglomerative Clustering (complete linkage)')
# Out:
# Silhouette Score: 0.387
# Davies-Bouldin Score: 0.894

# %% [markdown]
# ### Bisecting Clustering

# %%
from sklearn.cluster import BisectingKMeans

bkmeans = BisectingKMeans(3, bisecting_strategy='largest_cluster')

apply_model(bkmeans, data, 'Bisecting KMeans Clustering')
# Out:
# Silhouette Score: 0.333
# Davies-Bouldin Score: 0.946

# %% [markdown]
# ### Trying out different feature engineering
#
# From the scores obtained and the visual representation of the clusters, it's obvious that we can eliminate Single and Complete linkage agglomerative clustering methods, and shall proceed with testing on average Agglomerative, Bisecting and K-Means clustering only.
#
# #### Simple PCA

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA

data_fe = PCA(n_components=2).fit_transform(data)

# %%
apply_model(kmeans, data_fe, 'KMeans Clustering (PCA)')
# Out:
# Silhouette Score: 0.414
# Davies-Bouldin Score: 0.844

# %%
apply_model(agg, data_fe, 'Agglomerative Clustering (average linkage) (PCA)')
# Out:
# Silhouette Score: 0.387
# Davies-Bouldin Score: 0.894

# %%
apply_model(bkmeans, data_fe, 'Bisecting KMeans Clustering (PCA)')
# Out:
# Silhouette Score: 0.333
# Davies-Bouldin Score: 0.946

# %% [markdown]
# #### Standard scaling

# %%
data_fe = StandardScaler().fit_transform(data)

# %%
apply_model(kmeans, data_fe, 'KMeans Clustering (StandardScaler)')
# Out:
# Silhouette Score: 0.414
# Davies-Bouldin Score: 0.844

# %%
apply_model(agg, data_fe, 'Agglomerative Clustering (average linkage) (StandardScaler)')
# Out:
# Silhouette Score: 0.402
# Davies-Bouldin Score: 0.865

# %%
apply_model(bkmeans, data_fe, 'Bisecting KMeans Clustering (StandardScaler)')
# Out:
# Silhouette Score: 0.351
# Davies-Bouldin Score: 0.861

# %% [markdown]
# #### Min max scaling

# %%
data_fe = MinMaxScaler().fit_transform(data)

# %%
apply_model(kmeans, data_fe, 'KMeans Clustering (MinMaxScaler)')
# Out:
# Silhouette Score: 0.416
# Davies-Bouldin Score: 0.842

# %%
apply_model(agg, data_fe, 'Agglomerative Clustering (average linkage) (MinMaxScaler)')
# Out:
# Silhouette Score: 0.408
# Davies-Bouldin Score: 0.872

# %%
apply_model(bkmeans, data_fe, 'Bisecting KMeans Clustering (MinMaxScaler)')
# Out:
# Silhouette Score: 0.350
# Davies-Bouldin Score: 0.873

# %% [markdown]
# ### Final model selection
#
# #### Best models (By score)
#
# 1. K-means
# 2. Agglomerative (average linkage)
# 3. Bisecting
#
# #### Best feature engineering (By boost in score)
#
# 1. PCA
# 2. Standard scaler
# 3. MinMax scaler
# 4. RAW
#
# #### The final selection and why?
#
# I am going to select Agglomerative clustering with average linkage and PCA as the feature engineering technique!
#
# We have to consider the fact that the scores we have used to measure the performance of the algorithm is not the most optimum. We choose Agglomerative over K-Means because it is more tolerant to both convex and concave shaped clusters while K-Means is not.
#
# Also consider the fact that both the algorithms give pretty respectible scores.

# %%
## Save the clusters obtained from agglomerative clustering with average linkage with PCA

data_fe = PCA(n_components=2).fit_transform(data)
clusters = agg.fit_predict(data_fe)

np.savetxt('clusters.csv', clusters, delimiter=',', fmt='%d', header='Cluster', comments='')
